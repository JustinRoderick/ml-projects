# %% [markdown]
# Justin Roderick<div>
# CAP 4611<div>
# 5239523

# %% [markdown]
# # Homework 5
#
# This homework asks you to perform various experiments with ensemble methods.
#
# The dataset is the same real estate dataset we previously used from:
#
# https://www.kaggle.com/datasets/mirbektoktogaraev/madrid-real-estate-market
#
# You will write code and discussion into code and text cells in this notebook.
#
# If a code block starts with TODO:, this means that you need to write something there.
#
# There are also markdown blocks with questions. Write the answers to these questions in the specified locations.
#
# Some code had been written for you to guide the project. Don't change the already written code.
#
# ## Grading
# The points add up to 10. Extensive partial credit will be offered. Thus, make sure that you are at least attempting all problems.
#
# Make sure to comment your code, such that the grader can understand what different components are doing or attempting to do.

# %%
import numpy as np
import pandas as pd
import sklearn.linear_model
import sklearn.metrics
import sklearn.ensemble

# %% [markdown]
# # A. Setup.
#
# In this project we are going to work in a multi-variable setting.
#
# This time, there are 7 explanatory variables: ``sq_mt_built``, ``n_rooms``, ``n_bathrooms``, ``is_renewal_needed``, ``is_new_development`` and ``has_fitted_wardrobes``.
#
# We will first create the training and test data while doing some minimal data cleaning.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Reading the CSV file
df = pd.read_csv('/content/drive/MyDrive/houses_Madrid.csv')
#print(f"The columns of the database {df.columns}")

xfields = ["sq_mt_built", "n_rooms", "n_bathrooms", "has_individual_heating", \
           "is_renewal_needed", "is_new_development", "has_fitted_wardrobes"]
yfield = ["buy_price"]
# print (xfields + yfield)
dfsel = df[xfields + yfield]
dfselnona = dfsel.dropna()
df_shuffled = dfselnona.sample(frac=1) # shuffle the rows
x = df_shuffled[xfields].to_numpy(dtype=np.float64)
y = df_shuffled[yfield].to_numpy(dtype=np.float64)
print(x.shape)
training_data_x = x[:8000]
training_data_y = y[:8000]
test_data_x = x[8000:]
test_data_y = y[8000:]
print(f"Training data is composed of {len(training_data_x)} samples.")
print(f"Test data is composed of {len(test_data_x)} samples.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (9764, 7)
# Training data is composed of 8000 samples.
# Test data is composed of 1764 samples.

# %% [markdown]
# # B. Creating a linear regression multi-variable baseline.
#
# In this section we make a linear regression predictor for the multi-variable case. We also check the performance of the resulting regressor, and print the error.
#
# This part is had been done for you, such that the work does not depend on you importing parts from the previous projects.
#
# You will need to adapt this for the other models.

# %%
# training the linear regressor
regressor = sklearn.linear_model.LinearRegression()
regressor.fit(training_data_x, training_data_y)
# We will create the predictions yhat for every x from the training data. We will do this one at a time. This is not an efficient way to do it, but it allows you to write and debug functions that return a scalar number
yhats = []
for x in test_data_x:
    yhat = regressor.predict([x])
    yhats.append(yhat[0])

# Now, print some examples of the quality of the classifier
examples = [45, 67, 170, 189, 207]
for i in examples:
    x = test_data_x[i]
    y = test_data_y[i]
    yhat = regressor.predict([x])[0][0]
    print(f"House {i} with {x[0]} sqmt was sold for {y} euros, but our system predicted {yhat:.2f}")

# Now calculate the root mean square error on the resulting arrays
error = sklearn.metrics.mean_squared_error(yhats, test_data_y, squared=False)
print(f"The mean square error of the linear regression is {error:.2f} euro")
# Out:
# House 45 with 118.0 sqmt was sold for [517000.] euros, but our system predicted 461202.84
# House 67 with 381.0 sqmt was sold for [1390000.] euros, but our system predicted 1889149.60
# House 170 with 50.0 sqmt was sold for [310000.] euros, but our system predicted 138998.01
# House 189 with 57.0 sqmt was sold for [169000.] euros, but our system predicted 235047.32
# House 207 with 110.0 sqmt was sold for [339000.] euros, but our system predicted 497840.29
# The mean square error of the linear regression is 406971.78 euro

# %% [markdown]
# # P1: Random Forest using sklearn (5 points)
#
# Use the RandomForestRegressor function from sklearn to predict the prices of the house. Print the resulting error and samples, similar to the way in Section B.
#
# Experiment with the settings of the hyperparameters: n_estimators (try at least values 10, 25, 100, 200) and max_depth (try at least values 1, 2, 4, 8, 16 and None).
#
# Retain the hyperparameter value that gives you the best result.

# %%
from sklearn.ensemble import RandomForestRegressor

training_data_y = training_data_y.ravel()
test_data_y = test_data_y.ravel()

# Define hyperparameter settings to test with
n_estimators_list = [10, 25, 100, 200]
max_depth_list = [1, 2, 4, 8, 16, None]

best_error = float('inf')
best_params = {}

examples = [45, 67, 170, 189, 207]

# Iterate over hyperparameter settings
for n_estimators in n_estimators_list:
    for max_depth in max_depth_list:
        # Create and train the RandomForestRegressor
        model = RandomForestRegressor(n_estimators=n_estimators, max_depth=max_depth, random_state=42)
        model.fit(training_data_x, training_data_y)

        # Predict on test data
        predictions = model.predict(test_data_x)

        # Calculate mean squared error
        mse = sklearn.metrics.mean_squared_error(predictions, test_data_y, squared=False)

        # Print results for those parameters
        print(f"n_estimators={n_estimators}, max_depth={max_depth}, MSE={mse}")

        # Print house prices for each set of parameters
        for i in examples:
          print(f"House {i} sold for {test_data_y[i]} euros, but Random Forest predicted it to sell for {predictions[i]} euros")
        print()

        # Check if this model has the best performance so far
        if mse < best_error:
            best_error = mse
            best_params = {'n_estimators': n_estimators, 'max_depth': max_depth}

# Print the best hyperparameters and it's error
print(f"Best hyperparameters: {best_params}")
print(f"Best MSE: {best_error}")
# Out:
# n_estimators=10, max_depth=1, MSE=520014.3999997453
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 447239.5146211862 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1811197.3714800484 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 447239.5146211862 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 447239.5146211862 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 447239.5146211862 euros
#
# n_estimators=10, max_depth=2, MSE=430504.11924503674
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 329320.62382850307 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1576214.1861561022 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 329320.62382850307 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 329320.62382850307 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 329320.62382850307 euros
#
# n_estimators=10, max_depth=4, MSE=395159.9098552061
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 497367.1830865856 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2050915.3429432448 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 232848.96818002113 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 232848.96818002113 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 386109.7627827604 euros
#
# n_estimators=10, max_depth=8, MSE=377968.2640125796
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 417781.48378384404 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2267799.99414785 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 203384.9305570045 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 214768.1335425422 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 474275.28761480236 euros
#
# n_estimators=10, max_depth=16, MSE=410163.26530315256
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 426210.843045843 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2405000.0 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 194184.92352846434 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 219248.59486918309 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 531280.529878618 euros
#
# n_estimators=10, max_depth=None, MSE=414278.5416347473
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 426934.3074980575 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2405000.0 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 194750.21455235584 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 213781.2244232376 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 531820.529878618 euros
#
# n_estimators=25, max_depth=1, MSE=519104.73069954856
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 446002.1286161894 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1808550.5355949537 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 446002.1286161894 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 446002.1286161894 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 446002.1286161894 euros
#
# n_estimators=25, max_depth=2, MSE=430129.03374024964
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 328824.48384555394 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1587031.516107544 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 328824.48384555394 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 328824.48384555394 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 328824.48384555394 euros
#
# n_estimators=25, max_depth=4, MSE=395245.5129622627
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 485767.9156834074 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2050556.1309749084 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 232513.21478437496 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 232513.21478437496 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 400610.8949195875 euros
#
# n_estimators=25, max_depth=8, MSE=373898.3391906472
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 426328.78315827675 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2412919.7986640492 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 202024.24123417682 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 214863.6823827956 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 485449.0282837353 euros
#
# n_estimators=25, max_depth=16, MSE=399686.16738066747
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 418489.6455553595 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2708066.666666666 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 192578.78558247146 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 222246.1241068844 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 545695.4240726593 euros
#
# n_estimators=25, max_depth=None, MSE=402473.59523878945
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 417906.3843574726 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2677817.5066666664 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 194322.4708449819 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 219712.53861913804 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 548025.6804829157 euros
#
# n_estimators=100, max_depth=1, MSE=518063.95699993375
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 444916.004763447 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1807285.3069835347 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 444916.004763447 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 444916.004763447 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 444916.004763447 euros
#
# n_estimators=100, max_depth=2, MSE=428292.68913736823
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 329688.809266428 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1584141.340931898 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 329688.809266428 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 329688.809266428 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 329688.809266428 euros
#
# n_estimators=100, max_depth=4, MSE=394070.74164519407
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 487898.382387191 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1982253.8475424633 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 233455.1052379864 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 233455.1052379864 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 398464.94007846655 euros
#
# n_estimators=100, max_depth=8, MSE=370120.75537947804
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 426131.63195792004 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2397234.82218005 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 201592.15405511457 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 220748.10931755893 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 485658.5862099345 euros
#
# n_estimators=100, max_depth=16, MSE=394094.55771315383
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 432528.5510745108 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2643756.4101594896 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 191510.34202442973 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 222392.4076145464 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 529999.0303705862 euros
#
# n_estimators=100, max_depth=None, MSE=396004.01092549483
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 435762.4744317218 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2663994.3766666665 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 192069.2788765952 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 220391.0497492584 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 531828.1418750237 euros
#
# n_estimators=200, max_depth=1, MSE=515848.50552004925
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 442954.719445572 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1796755.120241067 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 442954.719445572 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 442954.719445572 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 442954.719445572 euros
#
# n_estimators=200, max_depth=2, MSE=427499.29453117255
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 329966.4781499196 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1576399.2851746627 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 328133.33456013195 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 328133.33456013195 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 328133.33456013195 euros
#
# n_estimators=200, max_depth=4, MSE=393748.337092572
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 488434.3288891939 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 1971618.2895487729 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 233263.27308493838 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 233263.27308493838 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 393514.51421509444 euros
#
# n_estimators=200, max_depth=8, MSE=369731.3457253359
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 428475.08222233603 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2395651.1425556317 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 200890.52737151366 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 223441.9604840571 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 480168.0297081715 euros
#
# n_estimators=200, max_depth=16, MSE=393892.5407068816
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 434057.29907696485 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2628018.8264032747 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 192859.90278263332 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 223423.90574862543 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 524830.4332430084 euros
#
# n_estimators=200, max_depth=None, MSE=395792.72673845175
# House 45 sold for 517000.0 euros, but Random Forest predicted it to sell for 436348.2768056787 euros
# House 67 sold for 1390000.0 euros, but Random Forest predicted it to sell for 2626676.358333333 euros
# House 170 sold for 310000.0 euros, but Random Forest predicted it to sell for 192577.00373362534 euros
# House 189 sold for 169000.0 euros, but Random Forest predicted it to sell for 222048.89382229932 euros
# House 207 sold for 339000.0 euros, but Random Forest predicted it to sell for 526613.8330369289 euros
#
# Best hyperparameters: {'n_estimators': 200, 'max_depth': 8}
# Best MSE: 369731.3457253359

# %% [markdown]
# # Questions:
# * Q: Do you find that Random Forest performs better than the previous approaches you implemented? Discuss.
# * A: It seems that Random Forest does perform better than multi-variable linear regression because the MSE of Random Forest was less.
# * Q: Explain the impact of the number of estimators and max tree depth hyperparameters on the accuracy. Which hyperparameter setting gives you the best value? Is this the same as the default settings in sklearn?
# * A: Overall the MSE decreased as the number of estimators went up, but when max depth went up past 8 the MSE would increase. I found that the most accurate hyperparamaters were 200 estimators and a max depth of 8. These are not the default sklearn values of 100 and none.
# * Q: Explain the impact of the hyperparameters on the training time.
# * A: As the number of n estimators and depth increased so did the training time.

# %% [markdown]
# # P2: AdaBoost using sklearn (5 points)
#
# Use the AdaBoost function from sklearn to predict the prices of the house. Print the resulting error and samples, similar to the way in Section B.
#
# Experiment with the settings of the hyperparameters: loss (try "linear", "square" and "exponential) and learning_rate (try at least values 0.2, 0.5, 1 and 2)

# %%
from sklearn.ensemble import AdaBoostRegressor
import time

# Define hyperparameter settings to test with
loss_list = ['linear', 'square', 'exponential']
learning_rate_list = [0.2, 0.5, 1, 2]

best_error = float('inf')
best_params = {}

examples = [45, 67, 170, 189, 207]

# Iterate over hyperparameter settings
for loss in loss_list:
    for learning_rate in learning_rate_list:

        start = time.time()
        # Create and train the AdaBoostRegressor
        model = AdaBoostRegressor(loss=loss, learning_rate=learning_rate, random_state=42)
        model.fit(training_data_x, training_data_y)

        # Predict on test data
        predictions = model.predict(test_data_x)

        # Calculate mean squared error
        mse = sklearn.metrics.mean_squared_error(predictions, test_data_y, squared=False)

        # Print results for those parameters
        print(f"loss={loss}, learning_rate={learning_rate}, MSE={mse}")

        # Print house prices for each set of parameters
        for i in examples:
            actual_price = test_data_y[i]
            predicted_price = predictions[i]
            print(f"House {i} sold for {actual_price} euros, but AdaBoost predicted it to sell for {predicted_price} euros")

        # Check if this model has the best performance so far
        if mse < best_error:
            best_error = mse
            best_params = {'loss': loss, 'learning_rate': learning_rate}
        end = time.time()
        print("The time of execution of these parameters was:", (end-start) * 10**3, "ms")
        print()

# Print the best hyperparameters and its error
print(f"Best hyperparameters: {best_params}")
print(f"Best MSE: {best_error}")
# Out:
# loss=linear, learning_rate=0.2, MSE=428379.1919990568
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 432959.7612244898 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 2448541.9903614456 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 299123.9259259259 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 299123.9259259259 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 343433.8618171985 euros
# The time of execution of these parameters was: 825.6127834320068 ms
#
# loss=linear, learning_rate=0.5, MSE=432660.490889168
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 395190.8390201225 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 2570472.181609195 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 308021.0689655172 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 308021.0689655172 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 353004.81945589447 euros
# The time of execution of these parameters was: 393.72706413269043 ms
#
# loss=linear, learning_rate=1, MSE=439241.6038628139
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 428621.8611925709 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 2734804.908148148 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 300360.3823620105 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 300360.3823620105 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 358886.01560121763 euros
# The time of execution of these parameters was: 272.56131172180176 ms
#
# loss=linear, learning_rate=2, MSE=455396.17849111656
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 418999.2702702703 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 3021668.3796909493 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 357968.7513464991 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 357968.7513464991 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 418999.2702702703 euros
# The time of execution of these parameters was: 83.86015892028809 ms
#
# loss=square, learning_rate=0.2, MSE=443179.35616635147
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 381396.37814070354 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 2548932.349436393 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 305980.8704125538 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 305980.8704125538 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 336986.19982185273 euros
# The time of execution of these parameters was: 360.98694801330566 ms
#
# loss=square, learning_rate=0.5, MSE=447130.50161198305
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 428621.8611925709 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 2764026.272962484 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 331430.2797450425 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 331430.2797450425 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 353479.0 euros
# The time of execution of these parameters was: 265.9463882446289 ms
#
# loss=square, learning_rate=1, MSE=474562.0140208237
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 428555.2173913043 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 2589961.6589026917 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 345660.8607395751 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 345660.8607395751 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 364590.6975158305 euros
# The time of execution of these parameters was: 276.64995193481445 ms
#
# loss=square, learning_rate=2, MSE=752057.2704808457
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 990000.0 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 1850000.0 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 990000.0 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 990000.0 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 990000.0 euros
# The time of execution of these parameters was: 195.73426246643066 ms
#
# loss=exponential, learning_rate=0.2, MSE=429444.0100899286
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 415961.7812105927 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 2504478.1874244255 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 310315.9214749061 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 310315.9214749061 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 363950.6591782442 euros
# The time of execution of these parameters was: 338.57083320617676 ms
#
# loss=exponential, learning_rate=0.5, MSE=462059.17859938776
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 486326.76150627615 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 2920643.2131519276 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 366278.19987507805 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 366278.19987507805 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 428621.8611925709 euros
# The time of execution of these parameters was: 309.74340438842773 ms
#
# loss=exponential, learning_rate=1, MSE=549563.2817460442
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 540549.3538461538 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 3176080.878274268 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 502090.6602209945 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 502090.6602209945 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 502090.6602209945 euros
# The time of execution of these parameters was: 286.20052337646484 ms
#
# loss=exponential, learning_rate=2, MSE=657724.5382903864
# House 45 sold for 517000.0 euros, but AdaBoost predicted it to sell for 654346.875 euros
# House 67 sold for 1390000.0 euros, but AdaBoost predicted it to sell for 3120116.37122807 euros
# House 170 sold for 310000.0 euros, but AdaBoost predicted it to sell for 654346.875 euros
# House 189 sold for 169000.0 euros, but AdaBoost predicted it to sell for 654346.875 euros
# House 207 sold for 339000.0 euros, but AdaBoost predicted it to sell for 654346.875 euros
# The time of execution of these parameters was: 280.0588607788086 ms
#
# Best hyperparameters: {'loss': 'linear', 'learning_rate': 0.2}
# Best MSE: 428379.1919990568

# %% [markdown]
# # Questions:
# * Q: Do you find that Adaboost performs better than the previous approaches you implemented? Discuss.
# * A: I found that Adaboost performed the worst compared to the other approaches as it had the highest MSE.
# * Q: Explain the impact of the loss and the learning_rate hyperparameters on the accuracy. Which hyperparameter setting gives you the best value? Is this the same as the default settings in sklearn?
# * A: The Linear loss function performed the best and the squared and exponential performed about the same. As the learning rate increased so did the error. The best parameters where linear with a lr of 0.2. These are almost the default values of sklearn which has linear and 1.0.
# * Q: Explain the impact of the hyperparameters on the training time.
# * A: As the learning rate increased the execution time decreased. It seems that overall the squared loss was faster.
